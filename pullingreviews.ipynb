# %%
import pickle
import json
from time import sleep
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path ='drive/My Drive/Colab Notebooks/reviews_Clothing_Shoes_and_Jewelry.json'
loadedjson = open(path, 'r')

# %%
count = 0 
allreviews = {}
for aline in loadedjson:
  count += 1
  if count % 100000 == 0:
    print(count)
  areview = eval(aline)
  allreviews[count] = areview

print(len(allreviews))
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# 4700000
# 4800000
# 4900000
# 5000000
# 5100000
# 5200000
# 5300000
# 5400000
# 5500000
# 5600000
# 5700000
# 5748920

# %%
from time import sleep


allnikeasins = []

for data in open('drive/My Drive/Colab Notebooks/allasins.txt', 'r'):
  asins = data.split(',')
  for anasin in asins:
    allnikeasins.append(anasin)
print(allnikeasins)
len(allnikeasins)
# Out:
# ['B003HFLWZM', 'B0059D31YU', 'B0037RIT06', 'B004TMT7EA', 'B000J2D62S', 'B004Y6Q8ZC', 'B00AMTXV3C', 'B007AT3TWU', 'B008Y49VTU', 'B009D4A3ME', 'B008H2G07K', 'B002P321KM', 'B00EA2FATU', 'B005OKXCWE', 'B00EQDZQTM', 'B00112CLDA', 'B00EKK62M6', 'B00B47C8HG', 'B005960BCW', 'B00FNA4J5E', 'B0058Z6QOQ', 'B0087RIFWI', 'B009D26B36', 'B005R48ZVA', 'B00DSRPW9Q', 'B00FQ14O82', 'B004TLVS6Q', 'B0059CIP7Y', 'B00595RU36', 'B000J2C2W8', 'B0058YHQUA', 'B0058XTAIW', 'B007L8X0AG', 'B008D55H8Y', 'B008D45OL0', 'B00E6B87R2', 'B005OBBPEU', 'B00DNGNRD0', 'B008EM2H1G', 'B00D966YB6', 'B00IHC8258', 'B008TT3Y8O', 'B006K4NRE6', 'B004QJ7URW', 'B000BL5T8Q', 'B0098H5LUA', 'B0029L8WP8', 'B00ANX32BS', 'B00DU0R0X2', 'B00B5NZCNG', 'B004UNXWDK', 'B007LO0ROC', 'B00BOVBY8G', 'B008BLK2R6', 'B002I9TUL6', 'B0059CKFEK', 'B003DQEJAK', 'B00C424PIA', 'B008F16YS8', 'B00EX6M3VG', 'B00BTD6EUM', 'B0085MTOSE', 'B00EVCZYZE', 'B00H5MJO7G', 'B00DMT0704', 'B007V2LKLS', 'B001U266NM', 'B0059D59TU', 'B00762HN3W', 'B008FGTM3W', 'B0058XNSXU', 'B0
# ...

# %%
nikereviews = {}
count = 0
for areview in allreviews:
  count += 1
  if count % 100000 == 0:
    print(count/5748920)
  
  thereview = allreviews[areview]
  theasin = thereview['asin']
  reviewworld = thereview['reviewerID']
  if theasin in allnikeasins:
    thekey = '%s.%s' % (theasin, reviewworld)
    nikereviews[thekey] = thereview
# Out:
# 0.017394571502125616
# 0.03478914300425123
# 0.05218371450637685
# 0.06957828600850247
# 0.08697285751062808
# 0.1043674290127537
# 0.12176200051487931
# 0.13915657201700493
# 0.15655114351913055
# 0.17394571502125616
# 0.19134028652338178
# 0.2087348580255074
# 0.226129429527633
# 0.24352400102975863
# 0.2609185725318843
# 0.27831314403400986
# 0.2957077155361355
# 0.3131022870382611
# 0.33049685854038674
# 0.34789143004251233
# 0.365286001544638
# 0.38268057304676356
# 0.4000751445488892
# 0.4174697160510148
# 0.43486428755314044
# 0.452258859055266
# 0.46965343055739167
# 0.48704800205951726
# 0.5044425735616429
# 0.5218371450637685
# 0.5392317165658941
# 0.5566262880680197
# 0.5740208595701454
# 0.591415431072271
# 0.6088100025743965
# 0.6262045740765222
# 0.6435991455786478
# 0.6609937170807735
# 0.678388288582899
# 0.6957828600850247
# 0.7131774315871503
# 0.730572003089276
# 0.7479665745914015
# 0.7653611460935271
# 0.7827557175956528
# 0.8001502890977784
# 0.8175448605999039
# ...

# %%
import json
json.dump(nikereviews, open('drive/My Drive/Colab Notebooks/allnikereviews.json','w'))
